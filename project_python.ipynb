# %% [markdown]
# <a href="https://colab.research.google.com/github/Gehtatp/tgsPython/blob/main/project_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pdb

# %% [markdown]
# #Builder#

# %% [markdown]
# ##Class Transaction##
#     """
#     A class to create transaction container object.
#     Holding all of the Transaction items, quantities and prices.
#     Attributes:
#     -----------
#     LOWER_AMOUNT : int
#         The minimum amount to get 1st level discount.
#     LOWER_DISCOUNT: float
#         The 1st level discount value in floating point. (5%)
#     MID_AMOUNT : int
#         The minimum amount to get 2nd level discount.
#     MID_DISCOUNT : float
#         The 2nd level discount value in floating point. (8%)
#     HIGH_AMOUNT : int
#         The minimum amount to get 3rd level discount.
#     HIGH_DISCOUNT : float
#         The 3rd level discount value in floating point. (10%)
#     TABLE_HEADERS : dictionary
#         Manual mapping of column to be displayed in Pandas DataFrame.
#     basket : dict
#         A dictionary to contain items that is stored in the transaction
#     Methods
#     -----------
#     add_item(name, qty, price)
#         Adding item to the container. When the exception is raised
#         it will print message.
#     update_item_name(name, new_name)
#         Replacing item name in the transaction container.
#     update_item_qty(name, new_qty)
#         Replacing item quantity of a particular item name.
#     update_item_price(name, new_price)
#         Replacing item price of a particular item name.
#     delete_item(name)
#         Deleting a single item in the Transaction container.
#     reset_transaction()
#         Deleting the entire item in the Transaction container.
#     check_order()
#         Checking all of the item in the container,
#         it will return in the form of table.
#     total_price()
#         Calculating total amount of the Transaction,
#         and it will discount the amount
#         if a certain transaction amount is reached.
#     """

# %% [markdown]
# def __init__(self):
#   """
#   Object constructor to trigger dictionary creation.
#   The self.container attributes will be triggered everytime the Class
#   is instantiated.
#   """
#
# def add_item(self, item_name, item_qty, item_price):
#   """
#   Adding item to Basket container.
#
#   Parameters
#   ----------
#   item_name : str (mandatory)
#     The name of the item.
#   item_qty : int (mandatory)
#     The quantity of the item.
#   item_price: int (mandatory)
#     The price of the item
#
#   Exception
#   ---------
#   ValueError
#     Found object type error for quantity and price.
#     Print invalid message.
#
#   Returns
#   -------
#   str
#     Success message (text/str) when the execption is not raised.
#     Failed message (text/str) when the execption is raised
#   """
#
# def update_item_name(self, item_name, new_item_name):
# """
#   Updating item_name to new_item_name.
#   If item_name is not in the self.basket, it will print error message
#
#   Parameters
#   ----------
#   item_name : str
#     The name of the item we want to replace
#   new_item_name : str
#     The new item name to replace the existing item name.
#
#   Exceptions
#   ----------
#   KeyError:
#     If the item_name is not in the self.basket, will print error message.
#
#   Returns
#   -------
#   str
#     Success message (text/str) when the execption is not raised.
#     Failure message (text/str) when the execption is raised.
#
#   """
#
#   def update_item_name(self, item_name, new_item_name):
#   """
#   Updating the current item name.
#   if the item is not in the self.basket, it will print error message
#
#   Parameters
#   ----------
#   item_name : str
#     The name of the item we want to replace
#   new_item_name : str
#     The new item name to replace the existing item name.
#
#   Exceptions
#   ----------
#   KeyError:
#     If the item is not in the self.basket, it will print error message.
#
#   Returns
#   -------
#   str
#     Success message (text/str) when the execption is not raised.
#           Failed message (text/str) when the execption is raised.
#   """
#
# def update_item_qty(self, item_name, new_item_qty):
#   """
#   Updatig the quantity of a certain item.
#   if the item is not in the self.basket, it will print error message.
#
#   Parameters
#   ----------
#   item_name : str
#     The name of the item we want to replace
#   new_item_qty : int
#     The new quantity value to replace the existing quantity.
#
#   Exceptions
#   ----------
#   KeyError:
#     If the item is not in the self.basket. it will print error message.
#   ValueError:
#     If the new qty (quantity) parameter is integer, it will print error message.
#   Returns
#   -------
#   str
#     Success message (text/str) when the execption is not raised.
#     Failed message (text/str) when the execption is raised.
#
# """
#
#
# def update_item_price(self, item_name, new_item_price):
#   """
#   Updatig the price of a certain item.
#   if the item is not in the self.basket, it will print error message.
#
#   Parameters
#   ----------
#   name : str
#     The name of the item we want to replace
#   new_price : int
#     The new value to replace the existing price of a certain item.
#
#   Exceptions
#   ----------
#   KeyError:
#     If the item is not in the self.basket, it will print error message.
#   ValueError:
#     If the value parameter is not in integer it will print error message.
#
#   Returns
#   -------
#   str
#     Success message (text/str) when the execption is not raised.
#     Failed message (text/str) when the execption is raised
#   """
#
#   def delete_item(self, item_name):
#   """
#     Deleting a single item in the self.basket.
#     If the item is not in the self.basket, it will print error message.
#
#     Parameters
#     ----------
#     item_name : str
#       The name of the item that should be replaced.
#
#     Exceptions
#     ----------
#       KeyError:
#         If the item is not in the self.basket. it will print error message.
#
#     Returns
#     -------
#     str
#       Success message (text/str) when the execption is not raised.
#       Failed message (text/str) when the execption is raised.
#
# """
#
#   def reset_transaction(self):
#   """
#     Deleting all items in the self.basket.
#     Deleting all items by clearing the self.basket
#
#     Returns
#     -------
#     str
#         Success message
#
#   """
#
#   def check_order(self):
#   """
#     Checking and verifying the self.basket.
#     Checking self.basket whether there are empty values or not.
#     If self.basket is empty it will return text
#     If self.basket is not empty it will contnue to check the basket for
#     invalid input or not from the submitted items, quantity and price.
#     If found, it will print invalid message.
#     If invalid data is not found, it will print a valid message.
#
#     Regardless the validity of the input, this method will print prepare
#     self.basket as Pandas DataFrame
#
#     Returns
#     -------
#     str
#       Total mount of all items in the basket.
#       If the container is empty it will return error message.
#   """

# %%
class Transaction:

    LOWER_AMOUNT = 200000
    LOWER_DISCOUNT = 0.05
    MID_AMOUNT = 300000
    MID_DISCOUNT = 0.08
    HIGH_AMOUNT = 500000
    HIGH_DISCOUNT = 0.1
    TABLE_HEADERS = [
        "Item Name", "Item Quantity", "Price/Item", "Total"
    ]

    def __init__(self):
      """
      Object constructor to trigger dictionary creation.
      The self.basket attributes will be triggered everytime the Class
      is instantiated.
      """
      
      self.basket = {}

    def add_item(self, item_name, item_qty, item_price):

      #try?
      self.basket[item_name] = [item_qty, item_price]

      message = "\nItem is successfully added"
      return message

    def update_item_name(self, item_name, new_item_name):
        
      try:
        self.basket[new_item_name] = self.container.pop(item_name)
        message = f"\nCurrent Item Name: {item_name}, "\
        + f"is Successfully Updated to: {new_item_name}"
      
      except (KeyError):
        message = f"\nItem {item_name} is Not found, "\
        + "please enter the correct name"

      return message

    def update_item_qty(self, item_name, new_item_qty):

      try:
          self.container[item_name][0] = int(new_item_qty)
          message = "\nUpdating Item Quantity is Successfull"
      except (KeyError):
          message = f"\nItem {item_name} is Not found "\
                    + "please enter the correct name"
      except (ValueError):
          message = f"\nNew Quantity Value: {new_item_qty} is Invalid"

      return message

    def update_item_price(self, item_name, new_item_price):
    
      try:
          self.container[item_name][1] = int(new_item_price)
          message = "\nUpdating Item Price is Successfull"
      except KeyError:
          message = f"\nItem {item_name} is Not found, "\
                    + "Please Enter The Correct Name"
      except ValueError:
          message = f"\nNew Price {new_item_price} Value is Invalid"

      return message

    def delete_item(self, item_name):

        try:
            del self.container[item_name]
            message = f"\nItem {item_name} Has Been Deleted Successfully"
        except KeyError:
            message = f"\nItem {item_name} is Not found, "\
                      + "Please Enter The Correct Name"

        return message
     
    def reset_transaction(self):

        self.container = {}
        message = "All Transactions Have Been Deleted Successfully"
        return message

    def check_order(self):

      # Checking whether the cart is empty or not
      if len(self.basket) == 0:
          message = "You Have No Transaction, " \
                    + "Please Add Item to Your Transaction"
          return message

      # Make a Deep Copy for the self.container to maintain data integrity
      basket_copy = deepcopy(self.basket)

      # Finding Missing Value or Invalid Value in the self.basket
      count = 0
      for key, value in basket_copy.items():
          try:
              if (key == "") or (value[0] == "") or (value[1] == "") \
                or (key.isdigit()) or (type(int(value[0])) is not int) \
                or (type(int(value[0])) is not int):
                count += 1
              else:
                amount = int(basket_copy[key][0]) \
                  * int(basket_copy[key][1])
                  basket_copy[key].append(amount)
          except (ValueError):
              count += 1

      # Deciding whether the input is valid or not
      if count == 0:
          print("\nYour Input is Valid\n")
      elif count > 0:
          print("\nYour Input is Invalid\n")

      # Gather the Value of the dictionary
      data = [value for value in container_copy.values()]

      # Insert the self.container dictionary key into list in the data
      for num, key in enumerate(container_copy):
          data[num].insert(0, key)

      # Transform the data into table with tabulate
      table = tabulate(data, self.TABLE_HEADERS)
      return table

if __name__ == "__main__":
    pass

# %%
    




    def total_price(self):
        """Calculate the amount of all transactions on the container.
        Discount will be calculated based on this rule:
        1. If an amount is more than 500000,
           it will calculte the total amount with 10% discount
        2. If an amount is more than 300000 but less than or equal to 500000 \
           it will calculate the total amount with 8% discount
        3. If an amount is more than 200000 but less than or equal to 300000  \
           it will calculate the total amount with 5% discount
        This method, first, will check whether the container is empty or not.
        if yes it will return a warning text.
        Returns
        -------
        str
            Total mount message if the container is not empty.
            If the container is empty it will return notification message
        """

        # Checking whether the cart is empty or not
        if len(self.container) == 0:
            return "You Have No Transaction, "\
                   + "Please Add Item to Your Transaction"

        # Calculating Total Amount
        try:
            total = 0
            for value in self.container.values():
                total += value[0]*value[1]
        except (TypeError):
            message = "You have Invalid Input Cannot Get The Total Price"
            return message

        # Deciding discount value
        if (total > self.HIGH_AMOUNT):
            print("CONGRATULATION, YOU GET 10% DISCOUNT!")
            total = total - (total*self.HIGH_DISCOUNT)
        elif (total > self.MID_AMOUNT) and (total <= self.HIGH_AMOUNT):
            print("CONGRATULATION, YOU GET 8% DISCOUNT!")
            total = total - (total*self.MID_DISCOUNT)
        elif (total > self.LOWER_AMOUNT) and (total <= self.MID_AMOUNT):
            print("CONGRATULATION, YOU GET 5% DISCOUNT!")
            total = total - (total*self.LOWER_DISCOUNT)

        # Create Message to be Shown
        message = f"\nThe products you buy are: {self.container}\n"\
                  + f"Your Total Amount of Purchase is {total}"
        return message

# %% [markdown]
# #SANDBOX

# %%
def new_basket_record(item_name, item_qty=1,item_paid=0):
  pricelist={'mangga_butir':('mangga_butir',10000,'butir')
           ,'mangga_kilo':('mangga_kilo',25000,'kg')
           ,'jambu_butir':('jambu_butir',2000,'butir')
           ,'jambu_kilo':('jambu_kilo',25000,'kg')
           ,'rambutan_butir':('rambutan_butir',1500,'butir')
           ,'rambutan_kilo':('rambutan_kilo',27500,'kg')
           ,'duku_butir':('duku_butir',25000,'butir')
           ,'duku_kilo':('duku_kilo',1000,'kg')
           ,'chery_butir':('chery_butir',2000,'butir')
           ,'chery_pak':('chery_pak',40000,'pak')
           ,'alpukat_butir':('alpukat_butir',12500,'butir')
           ,'alpukat_kilo':('alpukat_kilo',12500,'kg')
           ,'semangka_butir':('semangka_butir',25000,'butir')}

  basket_record=list()
  
  item_price=0
  if item_paid==0:
    item_price=pricelist[item_name][1]*item_qty
  else:
    #pdb.set_trace()
    item_qty=1
    item_qty=int(item_paid/(pricelist[item_name][1]*item_qty))   
    item_price=pricelist[item_name][1]*item_qty

  basket_record=(pricelist[item_name][0]
                 , item_qty
                 , item_price
                 , pricelist[item_name][2])

  return basket_record

# %%
#SANDBOX
#basket1=list()

def processBasket (iOperation, basket2, search_item=''):
  myreturn=list()
  iFound =0
  msg=''
  for row in range(len(basket2)):
    print(iOperation,basket2, search_item)
    if msg!='': print(msg) 
    if ((iOperation>=2) and (iOperation<=5)):
      if iOperation==1:
        basket2.clear()
        msg='Basket is now empty'
      else:
        pass
    else:
      if basket2[row][0]==search_item: 
        iFound+=1
        search_item='' #reset search_item
        #print (f'found at {row}: {basket2[row][0]}')

        basket_out=basket2.pop(row)
        
        if iOperation==2:
          #edit_name
          new_item='jambu_butir'
          basket_item=new_basket_record(new_item,0)
          basket2.append(basket_item)
          msg='One item added to Basket'
        elif iOperation==3:
          #edit_kuantiti
          new_qty=8
          basket_item=new_basket_record(basket_out[0],new_qty)
          basket2.append(basket_item)
          msg='One item in Basket is updated'
        elif iOperation==4:
          #edit_price
          new_paid=265000
          basket_item=new_basket_record(basket_out[0],basket_out[1],new_paid)
          basket2.append(basket_item)
          msg='One item in Basket is updated'
        elif iOperation==5:
          #delete_one_item
          msg='One item in Basket is deleted'
        
        iOperation=0    
      else:
        iFound=0
        msg='Item is not found in Basket'
        basket2=list()
        
  print('Search failed') if (not iFound) else print('Search success')
  #msg='Search failed' if (not iFound) else 'Search success'

  try:
    print(basket2)
  except (IndexError):
    print('nothing in Basket')
    basket2=list()
    msg='nothing in Basket'
  finally:
    myreturn=(msg,basket2,msg)
    return myreturn
    #return msg

# %%
basket2=list()

basket_item=new_basket_record('mangga_butir',10)
basket2.append(basket_item)
basket_item=new_basket_record('jambu_butir',20)
basket2.append(basket_item)
basket_item=new_basket_record('duku_kilo',10)
basket2.append(basket_item)
print(f'basket2 : {basket2}')

#basket1[item_name] = [item_qty, item_buy_price,item_unit]
#print(basket1)

#iFound =False
iFound =0
iOperation=0

#simulasi
search_item='mangga_butir'
iOperation=1
#search_item=buy_item
mymsg=processBasket (iOperation, basket2, search_item)

print(mymsg)
# Out:
# basket2 : [('mangga_butir', 10, 100000, 'butir'), ('jambu_butir', 20, 40000, 'butir'), ('duku_kilo', 10, 10000, 'kg')]
# 1 [('mangga_butir', 10, 100000, 'butir'), ('jambu_butir', 20, 40000, 'butir'), ('duku_kilo', 10, 10000, 'kg')] mangga_butir
# 0 [('jambu_butir', 20, 40000, 'butir'), ('duku_kilo', 10, 10000, 'kg')]
# 0 []
# Item is not found in Basket
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-ea4a12d2610e> in <module>
#      20 iOperation=1
#      21 #search_item=buy_item
# ---> 22 mymsg=processBasket (iOperation, basket2, search_item)
#      23
#      24 print(mymsg)
#
# <ipython-input-56-5e8297aac2e4> in processBasket(iOperation, basket2, search_item)
#      16         pass
#      17     else:
# ---> 18       if basket2[row][0]==search_item:
#      19         iFound+=1
#      20         search_item='' #reset search_item
#
# IndexError: list index out of range
